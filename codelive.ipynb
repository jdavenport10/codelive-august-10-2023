# %% [markdown]
# # CodeLive OpenAI

# %%
import openai
import os
import json
import time
import numpy as np

openai_key = json.load(open("openai.json"))["key"]
openai.api_key = openai_key

def cosine_similarity(a, b):
    return np.dot(a, b)/(np.linalg.norm(a) * np.linalg.norm(b))

# %% [markdown]
# # Open our Files
#
# We need to do a few things before we do anything fun with OpenAI.
#
# 1. Verify that all of our files are text (in our case they already are so we'll skip this)
#
# 2. Chunk our files into usable pieces
#     - OpenAI has a limitation on embedding input size
#     - We have a limit on context size in a prompt (we'll discuss what this means later)
#     - We want to make sure no piece of content falls "on the line" of a chunk break

# %%
files = os.listdir("./docs")
files
# Out:
# ['intro-programming-model.adoc',
#  'about-mule-message.adoc',
#  'cryptography-xml.adoc',
#  'tuning-test-validations.adoc',
#  'configuring-properties.adoc',
#  'cryptography-jce.adoc',
#  'about-flows.adoc',
#  'migration-core-poll.adoc',
#  'cryptography-pgp.adoc',
#  'package-a-mule-application.adoc',
#  'mule-server-notifications.adoc',
#  'for-each-scope-concept.adoc',
#  'mule-runtime-updates.adoc',
#  'batch-filters-and-batch-aggregator.adoc',
#  'using-maven-with-mule.adoc',
#  'common-dev-strategies.adoc',
#  'streaming-about.adoc',
#  'hardware-and-software-requirements.adoc',
#  'dynamic-evaluate-component-reference.adoc',
#  'test-mule-applications.adoc',
#  'about-classloading-isolation.adoc',
#  'reconnection-strategy-about.adoc',
#  'logging-in-mule.adoc',
#  'mule-upgrade-tool.adoc',
#  'transform-preview-transformation-output-design-center-task.adoc',
#  'migration-patterns-watermark.adoc',
#  'parse-template-reference.adoc',
#  'migration-core.adoc',
#  'logger-component-reference.adoc',
#  'business-events-in-components.adoc',
#  'hadr-guide.adoc',
#  'index-migration.adoc',
#  'migration-connectors-xml.adoc',
#  'configure-custom-serializers.adoc',
#  'round-robin.adoc',
#  'mule-deployment-model.adoc',
#  'dataweave.adoc',
#  'tuning-monitoring.adoc',
#  'deploy-to-cloudhub.adoc',
#  'global-elements.adoc',
#  'sharing-applications.adoc',
#  'migration-transports.adoc',
#  'mule-secure-token-service.adoc',
#  'third-party-software-in-mule.adoc',
#  'intro-java-integration.adoc',
#  'logging-mdc.adoc',
#  'flowref-about.adoc',
#  'mule-standalone.adoc',
#  'mule-data-types.adoc',
#  'intro-transformations.adoc',
#  'mule-app-dev-hellomule.adoc',
#  'mmp-concept.adoc',
#  'try-scope-concept.adoc',
#  'migration-transformers.adoc',
#  'migration-api-gateways-autodiscovery.adoc',
#  'tuning-batch-processing.adoc',
#  'cache-scope-invalidate.adoc',
#  'migration-api-gateways-policies.adoc',
#  'how-to-export-resources.adoc',
#  'intro-mule-message.adoc',
#  'tuning-logging.adoc',
#  'flow-component.adoc',
#  'tls-configuration.adoc',
#  'migration-core-splitter-aggregator.adoc',
#  'migration-connectors-jms.adoc',
#  'continuous-integration.adoc',
#  'intro-error-handlers.adoc',
#  'deploy-on-premises.adoc',
#  'try-scope-xml-reference.adoc',
#  'migration-connectors-http.adoc',
#  'deploying-to-multiple-environments.adoc',
#  'distributed-file-polling.adoc',
#  'migration-module-vm.adoc',
#  'hardening-your-mule-installation.adoc',
#  'about-transformers.adoc',
#  'about-mule-event.adoc',
#  'securing.adoc',
#  'mule-app-tutorial.adoc',
#  'single-resource-transaction.adoc',
#  'idempotent-message-validator.adoc',
#  'set-payload-transformer-reference.adoc',
#  'mule-app-properties-to-configure.adoc',
#  'custom-configuration-properties-provider.adoc',
#  'streaming-strategies-reference.adoc',
#  'reliability-patterns.adoc',
#  'migration-core-scatter-gather.adoc',
#  'cryptography.adoc',
#  'understanding-enterprise-integration-patterns-using-mule.adoc',
#  'about-mule-variables.adoc',
#  'fips-140-2-compliance-support.adoc',
#  'tuning-backend-server.adoc',
#  'tuning-app-design.adoc',
#  'migration-core-choice.adoc',
#  'setting-environment-variables.adoc',
#  'component-authorization-using-spring-security.adoc',
#  'cryptography-troubleshooting.adoc',
#  'migration-api-gateways.adoc',
#  'first-successful.adoc',
#  'transform-graphically-construct-mapping-design-center-task.adoc',
#  'tuning-guide.adoc',
#  'migration-core-enricher.adoc',
#  'scatter-gather-concept.adoc',
#  'migration-api-gateways-proxies.adoc',
#  'deploy-to-cloudhub-2.adoc',
#  'until-successful-scope.adoc',
#  'mule-app-dev.adoc',
#  'migration-connectors-file.adoc',
#  'mule-app-property-placeholders-spring.adoc',
#  'migration-connectors-ftp-sftp.adoc',
#  'migration-core-exception-strategies.adoc',
#  'transform-preview-transformation-output-studio-task.adoc',
#  'choosing-the-right-clustering-topology.adoc',
#  'transform-dataweave-xml-reference.adoc',
#  'choice-router-concept.adoc',
#  'authorization-grant-types.adoc',
#  'cache-scope-strategy.adoc',
#  'intro-engine.adoc',
#  'execution-engine.adoc',
#  'migration-module-wsc.adoc',
#  'batch-processing-concept.adoc',
#  'debugging-outside-studio.adoc',
#  'setting-up-ldap-provider-for-spring-security.adoc',
#  'variable-transformer-reference.adoc',
#  'migration-connectors-objectstore.adoc',
#  'deploying.adoc',
#  'migration-module-spring.adoc',
#  'about-mule-configuration.adoc',
#  'secure-configuration-properties.adoc',
#  'migration-dataweave.adoc',
#  'migration-secure-properties-placeholder.adoc',
#  'transform-move-transformations-separate-file-studio-task.adoc',
#  'tuning-domains.adoc',
#  'migration-security-filters.adoc',
#  'tuning-backpressure-maxconcurrency.adoc',
#  'transaction-management.adoc',
#  'migration-connectors-json.adoc',
#  'transform-add-another-output-transform-studio-task.adoc',
#  'build-app-practices.adoc',
#  'using-bitronix-to-manage-transactions.adoc',
#  'migration-intro.adoc',
#  'global-settings-configuration.adoc',
#  'cache-scope.adoc',
#  'intro-studio.adoc',
#  'intro-dataweave2.adoc',
#  'migration-connectors.adoc',
#  'transform-to-change-target-output-design-center.adoc',
#  'transform-input-output-structure-transformation-design-center-task.adoc',
#  'transform-input-output-structure-transformation-studio-task.adoc',
#  'async-scope-reference.adoc',
#  'migration-api-gateways-runtime-config.adoc',
#  'migration-process.adoc',
#  'migration-connectors-amqp.adoc',
#  'migration-core-foreach.adoc',
#  'cache-scope-to-configure.adoc',
#  'transform-component-about.adoc',
#  'batch-error-handling-faq.adoc',
#  'remove-variable.adoc',
#  'error-handling.adoc',
#  'installing-an-enterprise-license.adoc',
#  'migration-cheat-sheet.adoc',
#  'cryptography-reference.adoc',
#  'tuning-repeatable-nonrepeatable.adoc',
#  'mule-4-api-javadoc.adoc',
#  'raise-error-component-reference.adoc',
#  'intro-configuration.adoc',
#  'migration-aes.adoc',
#  'migration-prep.adoc',
#  'migration-connectors-email.adoc',
#  'consume-data-from-an-api.adoc',
#  'business-events.adoc',
#  'modularizing-your-configuration-files-for-team-development.adoc',
#  'feature-flagging.adoc',
#  'migration-module-validation.adoc',
#  'intro-packaging.adoc',
#  'deploy-to-rtf.adoc',
#  'distributed-locking.adoc',
#  'runtime-installation-task.adoc',
#  'migration-example-complex.adoc',
#  'whats-new-in-mule.adoc',
#  'transform-tips-transform-message-ui-studio.adoc',
#  'batch-phases.adoc',
#  'build-an-https-service.adoc',
#  'redelivery-policy.adoc',
#  'business-events-custom.adoc',
#  'migration-core-batch.adoc',
#  'creating-and-managing-a-cluster-manually.adoc',
#  'transform-workflow-create-mapping-ui-studio.adoc',
#  'xa-transactions.adoc',
#  'migration-core-until-successful.adoc',
#  'batch-reference.adoc',
#  'about-components.adoc',
#  'tuning-pooling-profiles.adoc',
#  'tuning-caching.adoc',
#  'mule-error-concept.adoc',
#  'index.adoc',
#  'migration-module-scripting.adoc',
#  'batch-job-instance-id.adoc',
#  'transform-graphically-construct-mapping-studio-task.adoc',
#  'mule-object-stores.adoc',
#  'migration-filters.adoc',
#  'migration-message-properties.adoc',
#  'parallel-foreach-scope.adoc',
#  'intro-expressions.adoc',
#  'starting-and-stopping-mule-esb.adoc',
#  'shared-resources.adoc',
#  'target-variables.adoc',
#  'on-error-scope-concept.adoc',
#  'notifications-configuration-reference.adoc',
#  'scheduler-concept.adoc',
#  'maven-reference.adoc',
#  'intro-connectors.adoc',
#  'profiling-mule.adoc',
#  'tuning-recommendations.adoc',
#  'rest-api-examples.adoc',
#  'migration-connectors-database.adoc',
#  'intro-overview.adoc',
#  'build-application-from-api.adoc',
#  'logging-and-debugging.adoc',
#  'configuring-mule-stacktraces.adoc',
#  'migrate-mule3-apimanager.adoc',
#  'reproducible-builds.adoc',
#  'mule-components.adoc',
#  'migration-patterns-reconnection-strategies.adoc',
#  'understanding-orchestration-using-mule.adoc',
#  'transform-workflow-create-mapping-ui-design-center.adoc',
#  'enable-verbose-logging.adoc',
#  'migration-mel.adoc',
#  'migration-munit-test-structure.adoc',
#  'correlation-id.adoc',
#  'set-transaction-id.adoc',
#  'advanced-mule-concepts.adoc',
#  'mule-app-properties-system.adoc',
#  'mule-high-availability-ha-clusters.adoc',
#  'transform-change-target-output-transformation-studio-task.adoc',
#  'migration-oauth2-provider.adoc']

# %%
chunks = []

CHUNK_SIZE = 2000
OVERLAP = 250

for file_to_read in files:
    f = open(f"./docs/{file_to_read}", "r")
    contents = f.read()
    chunks += [contents[i:i+CHUNK_SIZE] for i in range(0, len(contents), CHUNK_SIZE - OVERLAP)]

# %% [markdown]
# # Embed our Chunked Files
#
# We need to create embeddings for each of our files so that we can lookup based on similarity in our chatbot. This requires the use of OpenAI's Embeddings and then storage of that data.
#
# 1. Embed each chunk using text-embedding-ada-002
# 2. Store each chunk alongside it's embedding so we can use them both later on

# %% [markdown]
# ### Embeddings 101
#
# 1. Embeddings are like fingerprints for chunks of text
# 2. The "distance" between two "fingerprints" tells us how similar they are

# %%
chunk_1 = "Hello, my name is Joel!"
chunk_2 = "Hello, my name is Joe!"
chunk_3 = "This is a very different string from the other two."

embedding_1 = np.array(openai.Embedding.create(
    input=chunk_1,
    model="text-embedding-ada-002"
)['data'][0]['embedding'])

embedding_2 = np.array(openai.Embedding.create(
    input=chunk_2,
    model="text-embedding-ada-002"
)['data'][0]['embedding'])

embedding_3 = np.array(openai.Embedding.create(
    input=chunk_3,
    model="text-embedding-ada-002"
)['data'][0]['embedding'])

np.dot(embedding_1, embedding_2.T), np.dot(embedding_1, embedding_3.T)
# Out:
# (0.9153652814142736, 0.7330231509785115)

# %%
embeddings_dict = {}
rate_limit = 60
i = 1

for chunk in chunks:
    embedding = openai.Embedding.create(
        input=chunk, 
        model="text-embedding-ada-002"
    )['data'][0]['embedding']

    embeddings_dict[i] = {
        "vector": embedding, 
        "text": chunk
    }

    i += 1

    if i % rate_limit == 0:
        time.sleep(rate_limit)

# %% [markdown]
# # Save our Embeddings
#
# We need to save our embeddings to a file so we can load them in our API. We'll just save them as raw JSON here, but you could use a pickle file or some other compressed format if you would like. YOu'll just have to remember to load them up from that format in your API as we build that out.

# %%
with open("embeddings-new.json", "w") as outfile:
    json.dump(embeddings_dict, outfile)
